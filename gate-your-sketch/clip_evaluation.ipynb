# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/CMU/25fall/10623/T2IAdaptor
# Out:
# /content/drive/MyDrive/CMU/25fall/10623/T2IAdaptor

# %%
# !rm -rf /content/drive/MyDrive/CMU/25fall/10623/T2IAdaptor/diffusers
# !git clone https://github.com/Arlene036/diffusers.git

# %%
cd diffusers

# %%
# !pip install .
# Out:
# Processing /content/drive/MyDrive/CMU/25fall/10623/T2IAdaptor/diffusers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.36.0.dev0-py3-none-any.whl size=4587609 sha256=d3afc50ec39ffa59012ac711a89006fedb4ffaf29db4a67e51ac50beffe9c0ba
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w_7k02ke/wheels/5a/65/f8/b841cd3ffa4904f84cb92149d1d615801762a15c77f86d8a36
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.35.2
#     Uninstalling diffusers-0.35.2:
#       Successfully uninstalled diffusers-0.35.2
# ...

# %%
cd examples/t2i_adapter
# Out:
# /content/drive/MyDrive/CMU/25fall/10623/T2IAdaptor/diffusers/examples/t2i_adapter

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.1 MB/s eta 0:00:00
# ...

# %%
# !accelerate config
# Out:
# --------------------------------------------------------------------------------In which compute environment are you running?
# Please input a choice index (starting from 0), and press enter
#  ➔  This machine
#     AWS (Amazon SageMaker)

# %%
from accelerate.utils import write_basic_config
write_basic_config()

# %%
cd /content/drive/MyDrive/CMU/25fall/10623/T2IAdaptor
